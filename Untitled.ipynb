# %%
import wiki_analysis
import wiki_visual
import plotly.offline as py
py.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
wiki_en = wiki_analysis.Wiki_all_access("2019_en_wikidaily.csv", "utf-16")
wiki_en.article_heatmap('Princess Margaret, Countess of Snowdon',11)

# %%
wiki_en.barplot_month(10)

# %%
wiki_visual.lang_plot(wiki_en.get_df(), 'total', 'English')
# Out:
# Month: 2
# Month: 3
# Month: 4
# Month: 5
# Month: 6
# Month: 7
# Month: 8
# Month: 9
# Month: 10
# Month: 11
# Month: 12
# <div>
#
#
#             <div id="154de6ec-3fe8-4d35-8fa9-1ef76ba2fb53" class="plotly-graph-div" style="height:700px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("154de6ec-3fe8-4d35-8fa9-1ef76ba2fb53")) {
#                     Plotly.newPlot(
#                         '154de6ec-3fe8-4d35-8fa9-1ef76ba2fb53',
# ...
